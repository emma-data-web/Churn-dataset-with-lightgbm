# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import lightgbm  as lgb
import shap

# %%
df = pd.read_excel('Telco_customer_churn.xlsx')

# %%
df.head(10)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
# 5  4190-MFLUW      1  United States  California  Los Angeles     90020
# 6  8779-QRDMV      1  United States  California  Los Angeles     90022
# 7  1066-JKSGK      1  United States  California  Los Angeles     90024
# 8  6467-CHFZW      1  United States  California  Los Angeles     90028
# 9  8665-UTDHZ      1  United States  California  Los Angeles     90029
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# ...

# %%
pd.DataFrame(df)
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
# ...

# %%
# Display ALL rows (remove the limit)

pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sum(df['Churn Reason'].isnull())
# Out:
# 5174

# %%
df.head(2)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# ...

# %%
df.head(2)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# ...

# %%
df.drop(['CustomerID','Country','State','City'], axis =1, inplace=True)

# %%
df.head(3)
# Out:
#    Count  Zip Code                Lat Long   Latitude   Longitude  Gender  \
# 0      1     90003  33.964131, -118.272783  33.964131 -118.272783    Male
# 1      1     90005   34.059281, -118.30742  34.059281 -118.307420  Female
# 2      1     90006  34.048013, -118.293953  34.048013 -118.293953  Female
#
#   Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  \
# 0             No              DSL             Yes           Yes
# 1             No      Fiber optic              No            No
# 2            Yes      Fiber optic              No            No
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
df['Count'].value_counts()
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df['Senior Citizen'].value_counts()
# Out:
# Senior Citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %%
df['Tenure Months'].value_counts()
# Out:
# Tenure Months
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64

# %%
df['Internet Service'].value_counts()
# Out:
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    Count  Zip Code                Lat Long   Latitude   Longitude  Gender  \
# 0      1     90003  33.964131, -118.272783  33.964131 -118.272783    Male
# 1      1     90005   34.059281, -118.30742  34.059281 -118.307420  Female
#
#   Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  \
# 0             No              DSL             Yes           Yes
# 1             No      Fiber optic              No            No
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1                No           No           No               No
#
#          Contract Paperless Billing    Payment Method  Monthly Charges  \
# 0  Month-to-month               Yes      Mailed check            53.85
# ...

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Limited range of services                     44
# Long distance charges                         44
# Lack of affordable download/upload speed      44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# ...

# %%
df.head(1)
# Out:
#    Count  Zip Code                Lat Long   Latitude   Longitude Gender  \
# 0      1     90003  33.964131, -118.272783  33.964131 -118.272783   Male
#
#   Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0             No      No         No              2           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  \
# 0             No              DSL             Yes           Yes
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
#
#          Contract Paperless Billing Payment Method  Monthly Charges  \
# 0  Month-to-month               Yes   Mailed check            53.85
#
#   Total Charges Churn Label  Churn Value  Churn Score  CLTV  \
# 0        108.15         Yes            1           86  3239
#
#                    Churn Reason
# 0  Competitor made better offer

# %%
df.columns
# Out:
# Index(['Count', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender',
#        'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df[['Latitude', 'Longitude']] = df['Lat Long'].str.split(',', expand=True).astype(float)
df = df.drop(columns=['Lat Long'])

# %%
df
# Out:
#       Count  Zip Code   Latitude   Longitude  Gender Senior Citizen Partner  \
# 0         1     90003  33.964131 -118.272783    Male             No      No
# 1         1     90005  34.059281 -118.307420  Female             No      No
# 2         1     90006  34.048013 -118.293953  Female             No      No
# 3         1     90010  34.062125 -118.315709  Female             No     Yes
# 4         1     90015  34.039224 -118.266293    Male             No      No
# ...     ...       ...        ...         ...     ...            ...     ...
# 7038      1     92285  34.341737 -116.539416  Female             No      No
# 7039      1     92301  34.667815 -117.536183    Male             No     Yes
# 7040      1     92304  34.559882 -115.637164  Female             No     Yes
# 7041      1     92305  34.167800 -116.864330  Female             No     Yes
# 7042      1     92308  34.424926 -117.184503    Male             No      No
#
# ...

# %%
numurical_values_standardize = ['Zip Code','Latitude','Longitude',
                    'Monthly Charges','Total Charges','Churn Score','CLTV']

# %%
numerical_pipeline = Pipeline(steps=[
   ('scaler',StandardScaler()) 
])

# %%
categorical_data = ['Gender','Senior Citizen','Partner','Dependents','Tenure Months','Phone Service',
                    'Multiple Lines','Internet Service','Online Security','Online Backup','Device Protection',
                    'Tech Support','Streaming TV','Streaming Movies','Contract','Paperless Billing',
                    'Payment Method','Churn Reason']

# %%
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])

# %%
for col in categorical_data:
    df[col] = df[col].astype('category')

# %%
model = LGBMClassifier(class_weight='balanced')

# %%
pipeline = ColumnTransformer(transformers=[
    ('num_processing',numerical_pipeline,numurical_values_standardize),
    ('cat_processing',categorical_pipeline,categorical_data)
],verbose=True, remainder='passthrough', force_int_remainder_cols=False)

# %%
pipeline
# Out:
# ColumnTransformer(force_int_remainder_cols=False, remainder='passthrough',
#                   transformers=[('num_processing',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['Zip Code', 'Latitude', 'Longitude',
#                                   'Monthly Charges', 'Total Charges',
#                                   'Churn Score', 'CLTV']),
#                                 ('cat_processing',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder())]),
#                                  ['Gender', 'Senior Citizen', 'Partner',
#                                   'Dependents', 'Tenure Months',
#                                   'Phone Service', 'Multiple Lines',
# ...

# %%
final_pipeline = Pipeline(steps=[
    ('preprocessing',pipeline),
    ('model',model)
])

# %%
final_pipeline
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('num_processing',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Zip Code', 'Latitude',
#                                                    'Longitude',
#                                                    'Monthly Charges',
#                                                    'Total Charges',
#                                                    'Churn Score', 'CLTV']),
#                                                  ('cat_processing',
#                                                   Pipeline(steps=[('imputer',
# ...

# %%
param_grid = {
    'model__num_leaves': [15, 31, 63],
    'model__max_depth': [3, 5, 7],
    'model__learning_rate': [0.01, 0.05, 0.1],
    'model__n_estimators': [100, 200],
    'model__min_child_samples': [10, 20],
    'model__subsample': [0.8, 1.0],
    'model__colsample_bytree': [0.8, 1.0],
    'model__reg_alpha': [0, 0.1],
    'model__reg_lambda': [0, 0.1]
}

# %%
print(df['Churn Label'].value_counts())
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
print(df['Churn Label'].value_counts(normalize=True) * 100)
# Out:
# Churn Label
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
grid = GridSearchCV(
                    estimator=final_pipeline,
                    param_grid=param_grid,
                    cv = 5,
                    scoring= 'roc_auc',
                    verbose=2,
                    n_jobs=-1)

# %%
grid
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(force_int_remainder_cols=False,
#                                                           remainder='passthrough',
#                                                           transformers=[('num_processing',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Zip '
#                                                                           'Code',
#                                                                           'Latitude',
#                                                                           'Longitude',
#                                                                           'Monthly '
# ...

# %%
x_train, x_test, y_train, y_test  =train_test_split(df.drop(['Churn Label', 'Churn Value'], axis=1),df['Churn Label'], test_size=0.3,
                                                   random_state=101)

# %%
x_train['Total Charges'].isnull().sum()
# Out:
# 0

# %%
x_train
# Out:
#       Count  Zip Code   Latitude   Longitude  Gender Senior Citizen Partner  \
# 2823      1     95469  39.408634 -123.045516    Male             No      No
# 3908      1     95076  36.931654 -121.752383    Male             No      No
# 1539      1     94010  37.570280 -122.365778  Female             No      No
# 2792      1     95423  39.071160 -122.598542    Male             No      No
# 896       1     90623  33.850504 -118.039892    Male             No      No
# ...     ...       ...        ...         ...     ...            ...     ...
# 599       1     93060  34.402343 -119.094824    Male             No      No
# 5695      1     91436  34.152875 -118.486056  Female             No      No
# 1361      1     91702  34.174493 -117.870680  Female            Yes     Yes
# 1547      1     94104  37.791222 -122.402241  Female             No      No
# 4959      1     94037  37.540582 -122.509594  Female             No     Yes
#
# ...

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 1728 candidates, totalling 8640 fits
# [ColumnTransformer]  (1 of 3) Processing num_processing, total=   0.0s
# [ColumnTransformer]  (2 of 3) Processing cat_processing, total=   0.1s
# [ColumnTransformer] ..... (3 of 3) Processing remainder, total=   0.0s
# [LightGBM] [Info] Number of positive: 1280, number of negative: 3650
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1749
# [LightGBM] [Info] Number of data points in the train set: 4930, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
for col in x_train.columns:
    print(col)
    print(x_train[col].head())
# Out:
# Count
# 2823    1
# 3908    1
# 1539    1
# 2792    1
# 896     1
# Name: Count, dtype: int64
# Zip Code
# 2823    95469
# 3908    95076
# 1539    94010
# 2792    95423
# 896     90623
# Name: Zip Code, dtype: int64
# Lat Long
# 2823    39.408634, -123.045516
# 3908    36.931654, -121.752383
# 1539     37.57028, -122.365778
# 2792     39.07116, -122.598542
# 896     33.850504, -118.039892
# Name: Lat Long, dtype: object
# Latitude
# 2823    39.408634
# 3908    36.931654
# 1539    37.570280
# 2792    39.071160
# 896     33.850504
# Name: Latitude, dtype: float64
# Longitude
# 2823   -123.045516
# 3908   -121.752383
# 1539   -122.365778
# 2792   -122.598542
# 896    -118.039892
# Name: Longitude, dtype: float64
# Gender
# 2823      Male
# 3908      Male
# 1539    Female
# 2792      Male
# 896       Male
# Name: Gender, dtype: category
# Categories (2, object): ['Female', 'Male']
# Senior Citizen
# 2823    No
# 3908    No
# 1539    No
# 2792    No
# 896     No
# ...

# %%
mask = (df == ' ').any()
print(mask[mask])
# Out:
# Total Charges    True
# dtype: bool

# %%
df['Total Charges'] = df['Total Charges'].replace(' ', np.nan)

# %%
df['Total Charges'] = df['Total Charges'].astype(float)

# %%
print(df['Total Charges'].isna().sum())
# Out:
# 11

# %%
df.head(1)
# Out:
#    Count  Zip Code   Latitude   Longitude Gender Senior Citizen Partner  \
# 0      1     90003  33.964131 -118.272783   Male             No      No
#
#   Dependents Tenure Months Phone Service Multiple Lines Internet Service  \
# 0         No             2           Yes             No              DSL
#
#   Online Security Online Backup Device Protection Tech Support Streaming TV  \
# 0             Yes           Yes                No           No           No
#
#   Streaming Movies        Contract Paperless Billing Payment Method  \
# 0               No  Month-to-month               Yes   Mailed check
#
#    Monthly Charges  Total Charges Churn Label  Churn Value  Churn Score  CLTV  \
# 0            53.85         108.15         Yes            1           86  3239
#
#                    Churn Reason
# 0  Competitor made better offer

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   category
# dtypes: category(1)
# memory usage: 7.1 KB

# %%
y_pred= grid.predict(x_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array(['Yes', 'Yes', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))

 #Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.99      0.98      0.99      1524
#          Yes       0.96      0.97      0.97       589
#
#     accuracy                           0.98      2113
#    macro avg       0.98      0.98      0.98      2113
# weighted avg       0.98      0.98      0.98      2113
#
# Confusion Matrix:
# [[1501   23]
#  [  16  573]]

# %%
print("ROC AUC Score:")
print(roc_auc_score(y_test, grid.predict_proba(x_test)[:, 1]))
# Out:
# ROC AUC Score:
# 0.9978877852492547
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
df.head(1)
# Out:
#    Count  Zip Code   Latitude   Longitude Gender Senior Citizen Partner  \
# 0      1     90003  33.964131 -118.272783   Male             No      No
#
#   Dependents Tenure Months Phone Service Multiple Lines Internet Service  \
# 0         No             2           Yes             No              DSL
#
#   Online Security Online Backup Device Protection Tech Support Streaming TV  \
# 0             Yes           Yes                No           No           No
#
#   Streaming Movies        Contract Paperless Billing Payment Method  \
# 0               No  Month-to-month               Yes   Mailed check
#
#    Monthly Charges  Total Charges Churn Label  Churn Value  Churn Score  CLTV  \
# 0            53.85         108.15         Yes            1           86  3239
#
#                    Churn Reason
# 0  Competitor made better offer

# %%
df[['Gender', 'Churn Label', 'Monthly Charges']].head(100)
# Out:
#     Gender Churn Label  Monthly Charges
# 0     Male         Yes            53.85
# 1   Female         Yes            70.70
# 2   Female         Yes            99.65
# 3   Female         Yes           104.80
# 4     Male         Yes           103.70
# ..     ...         ...              ...
# 95    Male         Yes            85.65
# 96  Female         Yes           104.95
# 97    Male         Yes            50.65
# 98    Male         Yes            90.85
# 99    Male         Yes            19.95
#
# [100 rows x 3 columns]

# %%
pd.set_option('display.max_rows', 100)

# %%
# reset to default
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

# %%
df[df['Churn Value'] == 0]
# Out:
#       Count  Zip Code   Latitude   Longitude  Gender Senior Citizen Partner  \
# 1869      1     90001  33.973616 -118.249020  Female             No     Yes
# 1870      1     90002  33.949255 -118.246978    Male             No      No
# 1871      1     90004  34.076259 -118.310715    Male             No      No
# 1872      1     90007  34.027337 -118.285150    Male             No      No
# 1873      1     90008  34.008293 -118.346766  Female             No      No
# ...     ...       ...        ...         ...     ...            ...     ...
# 7038      1     92285  34.341737 -116.539416  Female             No      No
# 7039      1     92301  34.667815 -117.536183    Male             No     Yes
# 7040      1     92304  34.559882 -115.637164  Female             No     Yes
# 7041      1     92305  34.167800 -116.864330  Female             No     Yes
# 7042      1     92308  34.424926 -117.184503    Male             No      No
#
# ...

# %%
print("Best CV Score:", grid.best_score_)
print("Best Parameters:", grid.best_params_)
# Out:
# Best CV Score: 0.9985637842465753
# Best Parameters: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.05, 'model__max_depth': 5, 'model__min_child_samples': 10, 'model__n_estimators': 100, 'model__num_leaves': 31, 'model__reg_alpha': 0, 'model__reg_lambda': 0.1, 'model__subsample': 0.8}

# %%
lgbm_model = grid.best_estimator_.named_steps['model']
lgb.plot_importance(lgbm_model, max_num_features=20)
plt.title("Top 20 Feature Importances")
plt.show()

# %%
explainer = shap.TreeExplainer(lgbm_model)

# %%
print(lgbm_model.booster_.current_iteration())
# Out:
# 100

# %%
grid.best_estimator_.named_steps['model'].n_classes_
# Out:
# 2

# %%
explainer

# %%
# Compute SHAP values
X_test_transformed = grid.best_estimator_.named_steps['preprocessing'].transform(x_test)
shap_values = explainer(X_test_transformed)

# Plot summary
shap.summary_plot(shap_values, X_test_transformed)
